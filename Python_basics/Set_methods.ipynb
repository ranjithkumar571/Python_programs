# %%
colors = {"Green", "Red", "Blue"}
print(colors)
# Out:
# {'Green', 'Blue', 'Red'}

# %% [markdown]
#  Add two colors and remove two colors

# %%
colors.add( "Black" )
print(colors)
for x in colors:
    print(x) # Values will be printed randomly
# Out:
# {'Green', 'Blue', 'Black', 'Red'}
# Green
# Blue
# Black
# Red

# %%
colors.discard("Magenta") # No error if not present
print(colors)
# Out:
# {'Green', 'Blue', 'Black', 'Red'}

# %%
# colors.remove("Cyan") #this will error out as color not present in set
